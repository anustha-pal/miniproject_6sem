# %%
class brain_tumor:
    def import_libraries(self):
        import tensorflow as tf  
        from keras.preprocessing.image import ImageDataGenerator 
        
        import numpy as np  
        from keras.preprocessing import image  
    def image_data(self):
        from keras.preprocessing.image import ImageDataGenerator 
        train_datagen = ImageDataGenerator(rescale = 1./255,  
                                   shear_range = 0.2,  
                                   zoom_range = 0.2,  
                                   horizontal_flip = True) 
        self.training_set = train_datagen.flow_from_directory('../input/brain-tumor-classification-mri/Training',  
                                         target_size = (64, 64),  
                                         batch_size = 32,  
                                         class_mode = 'categorical') 
         
    def testing_set(self):
        from keras.preprocessing.image import ImageDataGenerator 
        test_datagen = ImageDataGenerator(rescale = 1./255) 
        self.test_set = test_datagen.flow_from_directory('../input/brain-tumor-classification-mri/Testing',  
                                            target_size = (64, 64),  
                                            batch_size = 32,  
                                            class_mode = 'categorical')
    def model_creation(self):
        import tensorflow as tf  
        self.cnn = tf.keras.models.Sequential()  
    
    def adding_layers(self):
        import tensorflow as tf
        self.cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))  
        self.cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2)) 
        self.cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'))  
        self.cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2)) 
        self.cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'))  
        self.cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2)) 
        self.cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'))  
        self.cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
    
    def flatten_layer(self):
        import tensorflow as tf
        self.cnn.add(tf.keras.layers.Flatten())
        
    def creating_NN(self):
        import tensorflow as tf
        self.cnn.add(tf.keras.layers.Dense(units=2048, activation='relu'))  
        self.cnn.add(tf.keras.layers.Dense(units=1024, activation='relu'))  
        self.cnn.add(tf.keras.layers.Dense(units=512, activation='relu')) 
        self.cnn.add(tf.keras.layers.Dense(units=256, activation='relu')) 
        self.cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))  
        self.cnn.add(tf.keras.layers.Dense(units=64, activation='relu'))  
        self.cnn.add(tf.keras.layers.Dense(units=32, activation='relu'))  
        self.cnn.add(tf.keras.layers.Dense(units=16, activation='relu'))  
        self.cnn.add(tf.keras.layers.Dense(units=4, activation='softmax'))  
        
    def model_summary(self):
        import tensorflow as tf 
        return self.cnn.summary()
    
    def compile_image(self):
        from keras.optimizers import Adam
        self.cnn.compile(optimizer = Adam(learning_rate=0.000001), loss = 'categorical_crossentropy', metrics = ['accuracy'])  
    def training_model(self):
        return self.cnn.fit(x = self.training_set, validation_data = self.test_set, epochs = 50)  
    
    def loading_image(self):
        test_image = imae.load_img('../input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(118).jpg', target_size = (64, 64))         
        return test_image
    
    def img_to_array(self):
        test_image1 = image.img_to_array(self.test_image)
        test_image1 = np.expand_dims(test_image1, axis = 0)
    def model_predict(self):
        result = self.cnn.predict(self.test_image1)
    def saving_model(self):
        self.cnn.save('brain_tumor_40.h5')
        
        
    def model_prediction(self):
        test_image = image.load_img('../input/brain-tumor-classification-mri/Testing/no_tumor/image(23).jpg', target_size = (64, 64))  
        test_image = image.img_to_array(test_image)  
        test_image = np.expand_dims(test_image, axis = 0)  
        result = cnn.predict(test_image)  
        training_set.class_indices  
        if result[0][0] == 0:  
             prediction = 'glioma_tumor'  
        elif result[0][0] == 1:  
             prediction = 'meningioma_tumor'  
        elif result[0][0] == 2:  
             prediction = 'no_tumor'  
        else:
             prediction = 'pituitary_tumor'

        print(prediction)

# %%
bt = brain_tumor()

# %%
bt.image_data()

# %%
bt.model_creation()

# %%
bt.adding_layers()

# %%
bt.flatten_layer()

# %%
bt.creating_NN()

# %%
bt.training_model()

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,  
                                   shear_range = 0.2,  
                                   zoom_range = 0.2,  
                                   horizontal_flip = True)

# %%
training_set = train_datagen.flow_from_directory('../input/brain-tumor-classification-mri/Training',  
                                                 target_size = (64, 64),  
                                                 batch_size = 32,  
                                                 class_mode = 'categorical')

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
test_set = test_datagen.flow_from_directory('../input/brain-tumor-classification-mri/Testing',  
                                            target_size = (64, 64),  
                                            batch_size = 32,  
                                            class_mode = 'categorical')

# %%
import tensorflow as tf
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))  
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2)) 
cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'))  
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2)) 
cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'))  
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2)) 
cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, activation='relu'))  
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=2048, activation='relu'))  
cnn.add(tf.keras.layers.Dense(units=1024, activation='relu'))  
cnn.add(tf.keras.layers.Dense(units=512, activation='relu')) 
cnn.add(tf.keras.layers.Dense(units=256, activation='relu')) 
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))  
cnn.add(tf.keras.layers.Dense(units=64, activation='relu'))  
cnn.add(tf.keras.layers.Dense(units=32, activation='relu'))  
cnn.add(tf.keras.layers.Dense(units=16, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=4, activation='softmax'))

# %%
from keras.optimizers import Adam
cnn.compile(optimizer = Adam(learning_rate=0.000001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 1)

# %%
import numpy as np  
from keras.preprocessing import image  
test_image = image.load_img('../input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(118).jpg', target_size = (64, 64))

# %%
test_image

# %%
test_image = image.img_to_array(test_image)

# %%
test_image = np.expand_dims(test_image, axis = 0)

# %%
result = cnn.predict(test_image)

# %%
result

# %%
training_set.class_indices

# %%
test_image1 = image.load_img('../input/brain-tumor-classification-mri/Testing/no_tumor/image(100).jpg', target_size = (64, 64))
test_image1

# %%
test_image1 = image.img_to_array(test_image1)

# %%
test_image1 = np.expand_dims(test_image1, axis = 0)

# %%
result = cnn.predict(test_image1)
result

# %%
cnn.save('brain_tumor_40.h5')

# %%
from tensorflow import keras
cnn = keras.models.load_model('./brain_tumor_40.h5')

# %%
training_set.class_indices

# %%
import numpy as np  
from keras.preprocessing import image  
test_image = image.load_img('../input/brain-tumor-classification-mri/Testing/no_tumor/image(23).jpg', target_size = (64, 64))  
test_image = image.img_to_array(test_image)  
test_image = np.expand_dims(test_image, axis = 0)  
result = cnn.predict(test_image)  
training_set.class_indices  
if result[0][0] == 0:  
  prediction = 'glioma_tumor'  
elif result[0][0] == 1:  
  prediction = 'meningioma_tumor'  
elif result[0][0] == 2:  
  prediction = 'no_tumor'  
else:
  prediction = 'pituitary_tumor'
  
print(prediction)
